# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('titanic.csv') #reading titanic.csv dataset
titanic #Getting the read table. It is 1257 * 9 table
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         0                       Allison, Miss. Helen Loraine
# 2          1         0               Allison, Mr. Hudson Joshua Creighton
# 3          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4          1         1                                Anderson, Mr. Harry
# 5          1         0                             Andrews, Mr. Thomas Jr
# 6          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 7          1         0                             Astor, Col. John Jacob
# 8          1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 9          1         1                      Aubart, Mme. Leontine Pauline
# 10         1         1                       Barber, Miss. Ellen "Nellie"
# 11         1         0                                Baumann, Mr. John D
# ...

# %%
titanic.head() #Getting head of the table to see first 5 records. 0-4 records appearing
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         0                     Allison, Miss. Helen Loraine  female
# 2       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 3       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 4       1         1                              Anderson, Mr. Harry    male
#
#     age  sibsp  parch      fare embarked
# 0  29.0      0      0  211.3375        S
# 1   2.0      1      2  151.5500        S
# 2  30.0      1      2  151.5500        S
# 3  25.0      1      2  151.5500        S
# 4  48.0      0      0   26.5500        S

# %%
titanic.tail() #Getting tail of the table to see last 5 records. 1252-1256 records appearing
# Out:
#       pclass  survived                                     name     sex   age  \
# 1252       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1253       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1254       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1255       3         0                     Youseff, Mr. Gerious    male  45.5
# 1256       3         0                        Yousif, Mr. Wazli    male   NaN
#
#       sibsp  parch     fare embarked
# 1252      0      0   9.5000        S
# 1253      1      0  14.4542        C
# 1254      1      0  14.4542        C
# 1255      0      0   7.2250        C
# 1256      0      0   7.2250        C

# %%
titanic.info() #Getting rows and column information summary. Same as summary function in R.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 9 columns):
# pclass      1257 non-null int64
# survived    1257 non-null int64
# name        1257 non-null object
# sex         1257 non-null object
# age         996 non-null float64
# sibsp       1257 non-null int64
# parch       1257 non-null int64
# fare        1257 non-null float64
# embarked    1257 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 88.5+ KB

# %%
titanic.describe() #Getting details of the titanic dataset
# Out:
#             pclass     survived         age        sibsp        parch  \
# count  1257.000000  1257.000000  996.000000  1257.000000  1257.000000
# mean      2.310263     0.382657   29.070783     0.501989     0.377884
# std       0.831791     0.486229   12.819750     1.056616     0.863035
# min       1.000000     0.000000    1.000000     0.000000     0.000000
# 25%       2.000000     0.000000   21.000000     0.000000     0.000000
# 50%       3.000000     0.000000   28.000000     0.000000     0.000000
# 75%       3.000000     1.000000   37.000000     1.000000     0.000000
# max       3.000000     1.000000   60.000000     8.000000     9.000000
#
#               fare
# count  1257.000000
# mean     32.720896
# std      51.127788
# min       0.000000
# 25%       7.895800
# 50%      14.400000
# 75%      31.000000
# max     512.329200

# %%
pd.crosstab(titanic['sex'],titanic['pclass'])
pd.crosstab(titanic['sex'],titanic['pclass']).plot(kind='bar') #sex and class relation

# %%
pd.crosstab(titanic['sex'],titanic['survived']).plot(kind='bar') #sex and survived relation

# %%
pd.crosstab(titanic['pclass'],titanic['survived']).plot(kind='bar') #class and survived relation

# %%
pd.crosstab(titanic['fare'],titanic['survived']).plot(kind='bar') #sex and class relation ***Need to create buckets
#pd.crosstab(titanic['age'],titanic['pclass'])#.plot(kind='bar') #sex and class relation ***Need to create buckets

# %%
pd.crosstab(titanic['embarked'],titanic['survived']).plot(kind='bar') #Embark and survived

# %%
pd.crosstab(titanic['age'],columns = 'Count').plot(kind='hist', alpha=.5)
#titanic.plot(kind='bar', x='age',y='survived')
#pd.crosstab(titanic['pclass'],columns = 'Count').plot(kind='bar') #sex and survived relation
